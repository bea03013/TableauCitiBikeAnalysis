# %%
import pandas as pd

# %%
bike1 = pd.read_csv("Raw/data-33zqP.csv")
bike1.head(3)
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  7/1/17                                              36737
# 1  7/2/17                                              43035
# 2  7/3/17                                              48193
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       107126
# 1                                       128397
# 2                                       130240
#
#    Total Annual Members (All Time)  \
# 0                           228157
# 1                           228306
# 2                           228473
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             2828
# 1                                             4314
# 2                                             3243
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            372
# 1                                            458
# ...

# %%
bike2 = pd.read_csv("Raw/data-7OLX8.csv")
bike2.head(3)
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/2018                                               5499
# 1  1/2/2018                                              18818
# 2  1/3/2018                                              24299
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        11483
# 1                                        39352
# 2                                        42853
#
#    Total Annual Members (All Time)  \
# 0                           253490
# 1                           253558
# 2                           253591
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                              123
# 1                                              125
# 2                                              164
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                              7
# 1                                             12
# ...

# %%
bike3 = pd.read_csv("Raw/data-cZMp8.csv")
bike3.head(3)
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/19                                              22145
# 1  1/2/19                                              38249
# 2  1/3/19                                              42181
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        44131
# 1                                        58975
# 2                                        62500
#
#    Total Annual Members (All Time)  \
# 0                           297823
# 1                           297908
# 2                           297976
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             2429
# 1                                             1062
# 2                                              969
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                             49
# 1                                             36
# ...

# %%
bike4 = pd.read_csv("Raw/data-FKjZg.csv")
bike4.head(3)
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  7/1/18                                              45265
# 1  7/2/18                                              58633
# 2  7/3/18                                              54882
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       120484
# 1                                       130122
# 2                                       113998
#
#    Total Annual Members (All Time)  \
# 0                           274813
# 1                           275016
# 2                           275157
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             4209
# 1                                             2702
# 2                                             2358
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            211
# 1                                            241
# ...

# %%
bike5 = pd.read_csv("Raw/data-K8j0z.csv")
bike5.head(3)
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/17                                              55503
# 1  10/2/17                                              65509
# 2  10/3/17                                              69105
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       139011
# 1                                       141748
# 2                                       135800
#
#    Total Annual Members (All Time)  \
# 0                           246193
# 1                           246402
# 2                           246566
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             3511
# 1                                             1408
# 2                                             1258
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            235
# 1                                            242
# ...

# %%
bike6 = pd.read_csv("Raw/data-MM5kM.csv")
bike6.head(3)
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/19                                              51399
# 1  4/2/19                                              57903
# 2  4/3/19                                              67924
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        75072
# 1                                        83399
# 2                                       108780
#
#    Total Annual Members (All Time)  \
# 0                           303223
# 1                           303386
# 2                           303552
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             1466
# 1                                             1483
# 2                                             3013
#
#    3-Day Passes Purchased (midnight to 11:59 pm)   Column 1
# 0                                             76  undefined
# ...

# %%
bike7 = pd.read_csv("Raw/data-pRAtm.csv")
bike7.head(3)
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/18                                              71387
# 1  10/2/18                                              73113
# 2  10/3/18                                              76769
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       120257
# 1                                       122234
# 2                                       129720
#
#    Total Annual Members (All Time)  \
# 0                           290631
# 1                           290788
# 2                           290947
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             2618
# 1                                             2666
# 2                                             3141
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            307
# 1                                            195
# ...

# %%
bike8 = pd.read_csv("Raw/data-tqNn6.csv")
bike8.head(3)
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/18                                              33148
# 1  4/2/18                                              22062
# 2  4/3/18                                              25883
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        94040
# 1                                        50418
# 2                                        59477
#
#    Total Annual Members (All Time)  \
# 0                           257811
# 1                           257889
# 2                           257942
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0                                             2363
# 1                                              297
# 2                                              189
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                            264
# 1                                             20
# ...

# %%
#Combine all Dataframes into one

# %%
daily = pd.concat([bike1, bike5], axis=0)
daily
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0     7/1/17                                              36737
# 1     7/2/17                                              43035
# 2     7/3/17                                              48193
# 3     7/4/17                                              49924
# 4     7/5/17                                              60321
# ..       ...                                                ...
# 87  12/27/17                                              16365
# 88  12/28/17                                              13419
# 89  12/29/17                                              13759
# 90  12/30/17                                               5956
# 91  12/31/17                                               6569
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        107126
# 1                                        128397
# ...

# %%
daily = pd.concat([daily, bike2], axis=0)
daily
# Out:
#          Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0      7/1/17                                              36737
# 1      7/2/17                                              43035
# 2      7/3/17                                              48193
# 3      7/4/17                                              49924
# 4      7/5/17                                              60321
# ..        ...                                                ...
# 85  3/27/2018                                              41354
# 86  3/28/2018                                              41880
# 87  3/29/2018                                              39288
# 88  3/30/2018                                              34784
# 89  3/31/2018                                              41779
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        107126
# 1                                        128397
# ...

# %%
daily = pd.concat([daily, bike8], axis=0)
daily
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    7/1/17                                              36737
# 1    7/2/17                                              43035
# 2    7/3/17                                              48193
# 3    7/4/17                                              49924
# 4    7/5/17                                              60321
# ..      ...                                                ...
# 86  6/26/18                                              80643
# 87  6/27/18                                              67647
# 88  6/28/18                                              50431
# 89  6/29/18                                              69856
# 90  6/30/18                                              54713
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        107126
# 1                                        128397
# 2                                        130240
# ...

# %%
daily = pd.concat([daily, bike4], axis=0)
daily
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    7/1/17                                              36737
# 1    7/2/17                                              43035
# 2    7/3/17                                              48193
# 3    7/4/17                                              49924
# 4    7/5/17                                              60321
# ..      ...                                                ...
# 87  9/26/18                                              68007
# 88  9/27/18                                              75370
# 89  9/28/18                                              57230
# 90  9/29/18                                              69321
# 91  9/30/18                                              66224
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        107126
# 1                                        128397
# 2                                        130240
# ...

# %%
daily = pd.concat([daily, bike7], axis=0)
daily
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0     7/1/17                                              36737
# 1     7/2/17                                              43035
# 2     7/3/17                                              48193
# 3     7/4/17                                              49924
# 4     7/5/17                                              60321
# ..       ...                                                ...
# 87  12/27/18                                              31169
# 88  12/28/18                                              12039
# 89  12/29/18                                              29037
# 90  12/30/18                                              22536
# 91  12/31/18                                              18936
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        107126
# 1                                        128397
# ...

# %%
daily = pd.concat([daily, bike3], axis=0)
daily
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    7/1/17                                              36737
# 1    7/2/17                                              43035
# 2    7/3/17                                              48193
# 3    7/4/17                                              49924
# 4    7/5/17                                              60321
# ..      ...                                                ...
# 85  3/27/19                                              54483
# 86  3/28/19                                              58538
# 87  3/29/19                                              59324
# 88  3/30/19                                              66672
# 89  3/31/19                                              32768
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        107126
# 1                                        128397
# 2                                        130240
# ...

# %%
daily = pd.concat([daily, bike6], axis=0)
daily
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    7/1/17                                              36737
# 1    7/2/17                                              43035
# 2    7/3/17                                              48193
# 3    7/4/17                                              49924
# 4    7/5/17                                              60321
# ..      ...                                                ...
# 66   6/6/19                                              81323
# 67   6/7/19                                              82908
# 68   6/8/19                                              78074
# 69   6/9/19                                              73954
# 70  6/10/19                                              37019
#
#     Miles traveled today (midnight to 11:59 pm)  \
# 0                                        107126
# 1                                        128397
# 2                                        130240
# ...

# %%
daily.to_csv("Data/daily.csv", index=False, header=True)
